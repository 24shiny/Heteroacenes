# %%
from hre_pyscf_batch_fixed import hre_from_smiles, ere_from_smiles
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import AllChem

# %%
smiles = [
    "c1ccc2ccccc2c1", 
    "C1C=Cc2ccccc12", 
    "C1=CC2=CC=CC2=C1", 
    "c1cc2cccccc2c1" 
]

# %%
mols = [Chem.MolFromSmiles(s) for s in smiles]
img = Draw.MolsToGridImage(mols, molsPerRow=4, subImgSize=(200,200))
img

# %% [markdown]
# HRE

# %%
hre_from_smiles(smiles[0])
# Out:
# geometric-optimize called with the following command line:
# /home/syj43/miniconda3/envs/chem-env/lib/python3.10/site-packages/ipykernel_launcher.py --f=/run/user/1000/jupyter/runtime/kernel-v3adebb71944e23eb1d9dde49650431169fe7c6e1e.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
# ...

# %%
hre_from_smiles(smiles[1])
# Out:
# geometric-optimize called with the following command line:
# /home/syj43/miniconda3/envs/chem-env/lib/python3.10/site-packages/ipykernel_launcher.py --f=/run/user/1000/jupyter/runtime/kernel-v3adebb71944e23eb1d9dde49650431169fe7c6e1e.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
# ...

# %%
hre_from_smiles(smiles[2])
# Out:
# geometric-optimize called with the following command line:
# /home/syj43/miniconda3/envs/chem-env/lib/python3.10/site-packages/ipykernel_launcher.py --f=/run/user/1000/jupyter/runtime/kernel-v3adebb71944e23eb1d9dde49650431169fe7c6e1e.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
# ...

# %%
hre_from_smiles(smiles[3])
# Out:
# geometric-optimize called with the following command line:
# /home/syj43/miniconda3/envs/chem-env/lib/python3.10/site-packages/ipykernel_launcher.py --f=/run/user/1000/jupyter/runtime/kernel-v3adebb71944e23eb1d9dde49650431169fe7c6e1e.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
# ...

# %% [markdown]
# ERE

# %%
ere_from_smiles(smiles[0])
# Out:
# geometric-optimize called with the following command line:
# /home/syj43/miniconda3/envs/chem-env/lib/python3.10/site-packages/ipykernel_launcher.py --f=/run/user/1000/jupyter/runtime/kernel-v3a6c079a0733c00939b69daed09b0f37ee46040af.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
# ...

# %%
ere_from_smiles(smiles[1])
# Out:
# geometric-optimize called with the following command line:
# /home/syj43/miniconda3/envs/chem-env/lib/python3.10/site-packages/ipykernel_launcher.py --f=/run/user/1000/jupyter/runtime/kernel-v3a6c079a0733c00939b69daed09b0f37ee46040af.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
# ...

# %%
ere_from_smiles(smiles[2])
# Out:
# geometric-optimize called with the following command line:
# /home/syj43/miniconda3/envs/chem-env/lib/python3.10/site-packages/ipykernel_launcher.py --f=/run/user/1000/jupyter/runtime/kernel-v3a6c079a0733c00939b69daed09b0f37ee46040af.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
# ...

# %%
ere_from_smiles(smiles[3])
